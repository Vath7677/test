# %% [markdown]
# #The Basic of guessing game

# %%
import random

# excersice point 1

# this use to random a number form 1 to 100
secret_number = random.randint(1,100)

guess = int(input("Enter guessing number(1-100): "))

# checking the condition it 's much to your answer or not
if guess == secret_number:
    print("You are right!")
elif guess > secret_number:
    print("Too high...! The number is",secret_number)
else:
    print("Too low...! The number is",secret_number)
# Out:
# Enter guessing number(1-100):  76
# Too high...! The number is 40

# %%
import random  

# excersice point 2 & 3

# this is an option to choice
options = ["rock", "paper", "scissors"]
playing = True

userScore = 0
computerScore = 0

print("--- Welcome to Rock, Paper, Scissors! ---")

while playing:  
    # input your choice
    user_choice = input("\nChoose Rock, Paper, or Scissors (or 'q' to quit): ").lower()

    # if u want to quite input q 
    if user_choice == 'q':
        playing = False
        break

    if user_choice not in options:
        print("Invalid choice, try again.")
        continue

        # this is computer random choice
    computer_choice = random.choice(options)
    print(f"Computer chose: {computer_choice}")
    
    if user_choice == computer_choice:
        print("It's a tie!")
    elif (user_choice == "rock" and computer_choice == "scissors") or \
         (user_choice == "paper" and computer_choice == "rock") or \
         (user_choice == "scissors" and computer_choice == "paper"):
        print("You win!")
        userScore += 1
    else:
        print("The computer wins!")
        computerScore += 1

    print(f"Your score: {userScore} | Computer score: {computerScore}")
print("Thanks for playing!")
# Out:
# --- Welcome to Rock, Paper, Scissors! ---
# Choose Rock, Paper, or Scissors (or 'q' to quit):  paper
# Computer chose: paper
# It's a tie!
# Your score: 0 | Computer score: 0
# Choose Rock, Paper, or Scissors (or 'q' to quit):  rock
# Computer chose: paper
# The computer wins!
# Your score: 0 | Computer score: 1
# Choose Rock, Paper, or Scissors (or 'q' to quit):  scissor
# Invalid choice, try again.
# Choose Rock, Paper, or Scissors (or 'q' to quit):  rock
# Computer chose: rock
# It's a tie!
# Your score: 0 | Computer score: 1
# Choose Rock, Paper, or Scissors (or 'q' to quit):  rock
# Computer chose: scissors
# You win!
# Your score: 1 | Computer score: 1
# Choose Rock, Paper, or Scissors (or 'q' to quit):  q
# Thanks for playing!

# %%
#making the new one

# %%
import random

# this use to random a number form 1 to 100
secret_number = random.randint(1,100)

playing = True 
while playing:
    guess = input("Enter guessing number(1-100)'q' to quite): ")

    if guess.lower() == 'q':
        playing = False
        break

    if not guess.isdigit():
        print("Invalid choice, try again.")
        continue

    guess_num = int(guess)
    
    # checking the condition it 's much to your answer or not
    if guess_num == secret_number:
        print("You are right!")
    elif guess_num > secret_number:
        print("Too high...!")
    else:
        print("Too low...!")

print("Thank your for playing, see u again next time!")
# Out:
# Enter guessing number(1-100)'q' to quite):  34
# Too low...!
# Enter guessing number(1-100)'q' to quite):  55
# Too low...!
# Enter guessing number(1-100)'q' to quite):  58
# Too low...!
# Enter guessing number(1-100)'q' to quite):  78
# Too high...!
# Enter guessing number(1-100)'q' to quite):  67
# Too low...!
# Enter guessing number(1-100)'q' to quite):  70
# Too low...!
# Enter guessing number(1-100)'q' to quite):  75
# Too high...!
# Enter guessing number(1-100)'q' to quite):  72
# Too high...!
# Enter guessing number(1-100)'q' to quite):  71
# You are right!
# Enter guessing number(1-100)'q' to quite):  q
# Thank your for playing, see u again next time!

# %%
import random  

# this is an option to choice
options = ["rock", "paper", "scissors"]
playing = True

userScore = 0
computerScore = 0

print("--- Welcome to Rock, Paper, Scissors! ---")

while playing:  
    # input your choice
    user_input = input("\nChoose Rock, Paper, or Scissors (or 'q' to quit): ").lower()

     # if u want to quite input q 
    if user_input == 'q':
        playing = False
        break
        
    if user_input == "1":
        user_choice = "rock"
    elif user_input == "2":
        user_choice = "paper"
    elif user_input == "3":
        user_choice = "scissors"
    else:
        user_choice = user_input

    if user_choice not in options:
        print("Invalid choice, try again.")
        continue

        # this is computer random choice
    computer_choice = random.choice(options)
    print(f"Computer chose: {computer_choice}")

    print(f"Your choice: {user_choice}")
    
    if user_choice == computer_choice:
        print("It's a tie!")
    elif (user_choice == "rock" and computer_choice == "scissors") or \
         (user_choice == "paper" and computer_choice == "rock") or \
         (user_choice == "scissors" and computer_choice == "paper"):
        print("\n==> You win!")
    else:
        print("\n==> The computer wins!")
        
print("Thanks for playing!, I hope i can see u next time!")
# Out:
# --- Welcome to Rock, Paper, Scissors! ---
# Choose Rock, Paper, or Scissors (or 'q' to quit):  1
# Computer chose: rock
# Your choice: rock
# It's a tie!
# Choose Rock, Paper, or Scissors (or 'q' to quit):  2
# Computer chose: scissors
# Your choice: paper
#
# ==> The computer wins!
# Choose Rock, Paper, or Scissors (or 'q' to quit):  3
# Computer chose: scissors
# Your choice: scissors
# It's a tie!
# Choose Rock, Paper, or Scissors (or 'q' to quit):  rock
# Computer chose: scissors
# Your choice: rock
#
# ==> You win!
