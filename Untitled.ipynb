# %% [markdown]
# #The game story exercise

# %%
place = input("Where place that you want to go ? :")
# Out:
# Where place that you want to go ? : kompot

# %%
food = input("what food that u eat?: ")
# Out:
# what food that u eat?:  pizza

# %%
feeling = input("Input your feeling in that in that situation :")
# Out:
# Input your feeling in that in that situation : happy

# %%
action = input("what do you do at that time :")
# Out:
# what do you do at that time : cooking

# %%
story = f"""On the holiday, I went on a trip to {place}. At that time, I felt very {feeling}.
My friend and I discussed what to eat, but we did not have any money in our pockets, so we decided to eat {food}.
that night, when we were going to {action}, a lot of animals came to eat our food.
In the end, we did not have anything to eat and went to sleep with tears in our eyes because we are hungry."""

# %%
print(story)
# Out:
# On the holiday, I went on a trip to kompot. At that time, I felt very happy.
# My friend and I discussed what to eat, but we did not have any money in our pockets, so we decided to eat pizza.
# that night, when we were going to cooking, a lot of animals came to eat our food.
# In the end, we did not have anything to eat and went to sleep with tears in our eyes because we are hungry.

# %%
print(type(story))
# Out:
# <class 'str'>

# %%
bill_amount = input("Enter the money: ")
print(bill_amount)
# covert it to float
payAmount = float(bill_amount)
print(totalAmount)
# Out:
# Enter the money:  100
# 100
# 100.0

# %% [markdown]
# ## Tip amount

# %%
tip = totalAmount * 0.15
print(tip)
# Out:
# 15.0

# %%
tip_percent = float(input("Enter percen that you want to give me a tip: "))
tip_amount = totalAmount * tip_percent
print(tip_amount)
# Out:
# Enter percen that you want to give me a tip:  0.12
# 12.0

# %%
total_pay = totalAmount - tip_percent
print(total_pay)
# Out:
# 99.88
